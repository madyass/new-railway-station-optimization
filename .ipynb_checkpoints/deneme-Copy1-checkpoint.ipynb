# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
import re
import importlib
from functions import *
from GA import *

# %% [markdown]
# # 1) DATASETS and Data Cleaning

# %% [markdown]
# ## a) Population Dataset

# %%
population_path = "/home/saydam/Desktop/2024-2025_itu/yzv202/project/github/datasets/population_with_coordinates.csv"

# %%
raw_population_df = pd.read_csv(population_path , header=None, sep=",")

# %%
raw_population_df = raw_population_df.dropna(how='all', axis=1)

# %%
raw_population_df.columns = raw_population_df.iloc[0]

# %%
raw_population_df = raw_population_df.drop(index=0).reset_index(drop=True)
raw_population_df = raw_population_df.loc[:, raw_population_df.columns.notna()]

# %%
raw_population_df[['latitude', 'longitude']] = raw_population_df['coordinate'].str.split(',', expand=True)

# %%
raw_population_df['latitude'] = raw_population_df['latitude'].astype(float)
raw_population_df['longitude'] = raw_population_df['longitude'].astype(float)
raw_population_df['population'] = raw_population_df['population'].astype(int)

# %%
population_df = raw_population_df[['population', 'neighborhood', 'township', 'neighborhood_code', 'latitude', 'longitude']]

# %%
population_df = population_df.dropna()

# %%
population_df.head()
# Out:
# 0  population       neighborhood    township neighborhood_code   latitude  \
# 0        4693     Adnan Menderes  Arnavutköy             40490  41.211179
# 1       47828            Anadolu  Arnavutköy             99359  41.186036
# 2       23116  Arnavutköy Merkez  Arnavutköy             40478  41.182546
# 3       10566            Atatürk  Arnavutköy             40482  41.190149
# 4       12829  Boğazköy İstiklal  Arnavutköy             40483  41.183488
#
# 0  longitude
# 0  28.700163
# 1  28.749463
# 2  28.737891
# 3  28.760125
# 4  28.768235

# %%
population_df.describe()
# Out:
# 0         population    latitude   longitude
# count     708.000000  708.000000  708.000000
# mean    21397.411017   41.029966   28.972329
# std     15943.770157    0.071404    0.193073
# min      2025.000000   40.817868   28.409171
# 25%     10279.250000   40.998081   28.854917
# 50%     17970.000000   41.028968   28.981120
# 75%     28527.750000   41.063456   29.109349
# max    112367.000000   41.269994   29.386538

# %% [markdown]
# ## b) Metro Station Dataset

# %%
stations_gdf = gpd.read_file("/home/saydam/Desktop/2024-2025_itu/yzv202/project/github/datasets/station.geojson")

# %%
print(stations_gdf.head())
# Out:
#                    ISTASYON                                      PROJE_ADI  \
# 0               Mehmet Akif            T1 Kabataş - Bağcılar Tramvay Hattı
# 1                  Soğanlık                   M4 Kadıköy - SGH Metro Hattı
# 2                   Aksaray  M1A Yenikapı - Atatürk Havalimanı Metro Hattı
# 3                 Olimpiyat            M9 Bahariye - Olimpiyat Metro Hattı
# 4  Sağmalcılar-Pancar Motor      T4 Topkapı - Mescid-i Selam Tramvay Hattı
#
#                PROJE_ASAMA HAT_TURU                                  MUDURLUK  \
# 0  Mevcut Hattaki İstasyon  Tramvay   Avrupa Yakası Raylı Sistemler Müdürlüğü
# 1  Mevcut Hattaki İstasyon    Metro  Anadolu Yakası Raylı Sistemler Müdürlüğü
# 2  Mevcut Hattaki İstasyon    Metro   Avrupa Yakası Raylı Sistemler Müdürlüğü
# 3  Mevcut Hattaki İstasyon    Metro   Avrupa Yakası Raylı Sistemler Müdürlüğü
# 4  Mevcut Hattaki İstasyon  Tramvay   Avrupa Yakası Raylı Sistemler Müdürlüğü
#
#                     geometry
# 0   POINT (28.88168 41.0058)
# 1   POINT (29.1924 40.91329)
# 2  POINT (28.94809 41.01201)
# 3  POINT (28.76723 41.07947)
# 4  POINT (28.90694 41.05728)

# %%
stations_gdf["lat"] = stations_gdf.geometry.x
stations_gdf["lon"] = stations_gdf.geometry.y

# %%
stations_df = stations_gdf[["ISTASYON", "PROJE_ADI", "HAT_TURU", "lat", "lon"]]

# %%
stations_df[["lat", "lon"]] = stations_df[["lon", "lat"]]
# Out:
# /tmp/ipykernel_109919/3141347488.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stations_df[["lat", "lon"]] = stations_df[["lon", "lat"]]

# %%
stations_df.head()
# Out:
#                    ISTASYON                                      PROJE_ADI  \
# 0               Mehmet Akif            T1 Kabataş - Bağcılar Tramvay Hattı
# 1                  Soğanlık                   M4 Kadıköy - SGH Metro Hattı
# 2                   Aksaray  M1A Yenikapı - Atatürk Havalimanı Metro Hattı
# 3                 Olimpiyat            M9 Bahariye - Olimpiyat Metro Hattı
# 4  Sağmalcılar-Pancar Motor      T4 Topkapı - Mescid-i Selam Tramvay Hattı
#
#   HAT_TURU        lat        lon
# 0  Tramvay  41.005800  28.881681
# 1    Metro  40.913288  29.192398
# 2    Metro  41.012008  28.948090
# 3    Metro  41.079466  28.767234
# 4  Tramvay  41.057280  28.906940

# %% [markdown]
# # Visulation

# %%
import folium


istanbul_coords = [41.0082, 28.9784]


map_istanbul = folium.Map(location=istanbul_coords, zoom_start=11, tiles='CartoDB positron')

for index, row in stations_df.iterrows():
    popup_text = f"{row['ISTASYON']}<br>{row['PROJE_ADI']}"
    folium.Marker(
        location=[row['lat'], row['lon']],
        popup=popup_text,
        icon=folium.Icon(color='blue' if row['HAT_TURU'] == 'Metro' else 'green', icon='train')
    ).add_to(map_istanbul)



map_istanbul
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_988ee1f00aea255164667d35740bb587 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_988ee1f00aea255164667d35740bb587&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_988ee1f00aea255164667d35740bb587 = L.map(
#                 &quot;map_988ee1f00aea255164667d35740bb587&quot;,
#                 {
#                     center: [41.0082, 28.9784],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6cd7b74499575dfdc7d8121da3ee3465 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6cd7b74499575dfdc7d8121da3ee3465.addTo(map_988ee1f00aea255164667d35740bb587);
#
#
#             var marker_319fade5f1a4ecde0bd4a6a491efe635 = L.marker(
#                 [41.0058001386, 28.881680707],
#                 {
# }
#             ).addTo(map_988ee1f00aea255164667d35740bb587);
#
#
#             var icon_1ac866dc4936456cad150b519afa1ac7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;train&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9f1d894a0db42fea49333a3740e79a6e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_029210c1b6f1da0e3c9f352e172c006e = $(`&lt;div id=&quot;html_029210c1b6f1da0e3c9f352e172c006e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mehmet Akif&lt;br&gt;T1 Kabataş - Bağcılar Tramvay Hattı&lt;/div&gt;`)[0];
#                 popup_9f1d894a0db42fea49333a3740e79a6e.setContent(html_029210c1b6f1da0e3c9f352e172c006e);
#
#
#
#         marker_319fade5f1a4ecde0bd4a6a491efe635.bindPopup(popup_9f1d894a0db42fea49333a3740e79a6e)
#         ;
#
#
#
#
#                 marker_319fade5f1a4ecde0bd4a6a491efe635.setIcon(icon_1ac866dc4936456cad150b519afa1ac7);
#
#
#             var marker_caa923ca1ab798f83b391fee953fea94 = L.marker(
#                 [40.9132883838, 29.1923983239],
#                 {
# }
#             ).addTo(map_988ee1f00aea255164667d35740bb587);
#
#
#             var icon_f6c7c46273f375feb206e06a65c6e130 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;train&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_75adad61b36378356f3f6e042f3502bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f82fed27caf2e71383aaa4b3465cb1e = $(`&lt;div id=&quot;html_1f82fed27caf2e71383aaa4b3465cb1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Soğanlık&lt;br&gt;M4 Kadıköy - SGH Metro Hattı&lt;/div&gt;`)[0];
#                 popup_75adad61b36378356f3f6e042f3502bd.setContent(html_1f82fed27caf2e71383aaa4b3465cb1e);
#
#
#
#         marker_caa923ca1ab798f83b391fee953fea94.bindPopup(popup_75adad61b36378356f3f6e042f3502bd)
#         ;
#
#
#
#
#                 marker_caa923ca1ab798f83b391fee953fea94.setIcon(icon_f6c7c46273f375feb206e06a65c6e130);
#
#
#             var marker_b86c7fd836c2f4c9c31f2dc6a41ddb62 = L.marker(
#                 [41.0120083811, 28.9480900733],
#                 {
# }
#             ).addTo(map_988ee1f00aea255164667d35740bb587);
#
#
#             var icon_088506c27adf539665c656e5bf2b5c30 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;train&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4e84d48bb9dcf1e70c66d5113c87841b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd7b02a1df89d8b438bc1fb6bf0ebfd2 = $(`&lt;div id=&quot;html_cd7b02a1df89d8b438bc1fb6bf0ebfd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aksaray&lt;br&gt;M1A Yenikapı - Atatürk Havalimanı Metro Hattı&lt;/div&gt;`)[0];
#                 popup_4e84d48bb9dcf1e70c66d5113c87841b.setContent(html_cd7b02a1df89d8b438bc1fb6bf0ebfd2);
#
#
#
#         marker_b86c7fd836c2f4c9c31f2dc6a41ddb62.b

# %%
m = folium.Map(location=istanbul_coords, zoom_start=10)


for _, row in population_df.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f"{row['neighborhood']} ({row['township']})\nNüfus: {row['population']}",
        tooltip=row['neighborhood']
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9f222ae1e2a5658aac877a12d55d413 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9f222ae1e2a5658aac877a12d55d413&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e9f222ae1e2a5658aac877a12d55d413 = L.map(
#                 &quot;map_e9f222ae1e2a5658aac877a12d55d413&quot;,
#                 {
#                     center: [41.0082, 28.9784],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_173c9a03cc1b92ec16372d88cb965fc7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_173c9a03cc1b92ec16372d88cb965fc7.addTo(map_e9f222ae1e2a5658aac877a12d55d413);
#
#
#             var marker_fdbb1a6ca20cdad8b2e786a35884d0ee = L.marker(
#                 [41.21117942200278, 28.70016339825508],
#                 {
# }
#             ).addTo(map_e9f222ae1e2a5658aac877a12d55d413);
#
#
#         var popup_2f57da3a04bfb5bc2f280c230da7a477 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd5a0f9ec60d62bf0300d35f7dead155 = $(`&lt;div id=&quot;html_bd5a0f9ec60d62bf0300d35f7dead155&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adnan Menderes (Arnavutköy) Nüfus: 4693&lt;/div&gt;`)[0];
#                 popup_2f57da3a04bfb5bc2f280c230da7a477.setContent(html_bd5a0f9ec60d62bf0300d35f7dead155);
#
#
#
#         marker_fdbb1a6ca20cdad8b2e786a35884d0ee.bindPopup(popup_2f57da3a04bfb5bc2f280c230da7a477)
#         ;
#
#
#
#
#             marker_fdbb1a6ca20cdad8b2e786a35884d0ee.bindTooltip(
#                 `&lt;div&gt;
#                      Adnan Menderes
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_5ebbbc048f5d83aec2bab7a91dd212fd = L.marker(
#                 [41.186036498559716, 28.74946286470569],
#                 {
# }
#             ).addTo(map_e9f222ae1e2a5658aac877a12d55d413);
#
#
#         var popup_88598b722de3d87da50a446b4723875d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a0728ae4f9d3b722a798336496efcae = $(`&lt;div id=&quot;html_0a0728ae4f9d3b722a798336496efcae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Anadolu (Arnavutköy) Nüfus: 47828&lt;/div&gt;`)[0];
#                 popup_88598b722de3d87da50a446b4723875d.setContent(html_0a0728ae4f9d3b722a798336496efcae);
#
#
#
#         marker_5ebbbc048f5d83aec2bab7a91dd212fd.bindPopup(popup_88598b722de3d87da50a446b4723875d)
#         ;
#
#
#
#
#             marker_5ebbbc048f5d83aec2bab7a91dd212fd.bindTooltip(
#                 `&lt;div&gt;
#                      Anadolu
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_412d27717cd3de8d0d2aac77d908c8e4 = L.marker(
#                 [41.182546301505184, 28.737890672938565],
#                 {
# }
#             ).addTo(map_e9f222ae1e2a5658aac877a12d55d413);
#
#
#         var popup_f43342df54384cfec7adf9403cf5d52e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ef1a8060f1fbd0d25db034e415bee44 = $(`&lt;div id=&quot;html_5ef1a8060f1fbd0d25db034e415bee44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arnavutköy Merkez (Arnavutköy) Nüfus: 23116&lt;/div&gt;`)[0];
#                 popup_f43342df54384cfec7adf9403cf5d52e.setContent(html_5ef1a8060f1fbd0d25db034e415bee44);
#
#
#
#         marker_412d27717cd3de8d0d2aac77d908c8e4.bindPopup(popup_f43342df54384cfec7adf9403cf5d52e)
#         ;
#
#
#
#
#             marker_412d27717cd3de8d0d2aac77d908c8e4.bindTooltip(
#                 `&lt;div&gt;
#                      Arnavutköy Merkez
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_7299dd60d8434129bda3a4954f0bca62 = L.marker(
#                 [41.190149302149145, 28.76012510805287],
#                 {
# }
#             ).addTo(map_e9f222ae1e2a5658aac877a12d55d413);
#
#
#         var popup_31b8e4afe9fd0c0d0ba61c87182e5aea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd92e240757d0a4f795b0258d662a17f = $(`&lt;div id=&quot;html_cd92e240757d0a4f795b0258d662a17f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Atatürk (Arnavutköy) Nüfus: 10566&lt;/div&gt;`)[0];
#                 popup_31b8e4afe9fd0c0d0ba61c87182e5aea.setContent(html

# %%
lat_min, lat_max = 40.977, 41.14
lon_min, lon_max = 28.70, 29.0

# %%
num_lat_grids = 30
num_lon_grids = 30

# %%
grid_list , candidate_stations = create_grid(
    lat_min = lat_min , lon_min = lon_min , lat_max = lat_max , lon_max = lon_max)

# %%
grid_df = pd.DataFrame(grid_list)
grid_df.head()
# Out:
#   grid_id  lat_start    lat_end  lon_start  lon_end
# 0  (0, 0)     40.977  40.982433      28.70    28.71
# 1  (0, 1)     40.977  40.982433      28.71    28.72
# 2  (0, 2)     40.977  40.982433      28.72    28.73
# 3  (0, 3)     40.977  40.982433      28.73    28.74
# 4  (0, 4)     40.977  40.982433      28.74    28.75

# %%
candidate_stations_df = pd.DataFrame(candidate_stations)
candidate_stations_df.head()
# Out:
#   station_id        lat     lon
# 0     (0, 0)  40.979717  28.705
# 1     (0, 1)  40.979717  28.715
# 2     (0, 2)  40.979717  28.725
# 3     (0, 3)  40.979717  28.735
# 4     (0, 4)  40.979717  28.745

# %%
candidate_stations_df.describe()
# Out:
#               lat         lon
# count  900.000000  900.000000
# mean    41.058500   28.850000
# std      0.047054    0.086603
# min     40.979717   28.705000
# 25%     41.017750   28.775000
# 50%     41.058500   28.850000
# 75%     41.099250   28.925000
# max     41.137283   28.995000

# %%
candidate_stations_df['TYPE'] = 'candidate'
stations_df['TYPE'] = 'existing'
# Out:
# /tmp/ipykernel_109919/535197162.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stations_df['TYPE'] = 'existing'

# %%
stations_df.head()
# Out:
#                    ISTASYON                                      PROJE_ADI  \
# 0               Mehmet Akif            T1 Kabataş - Bağcılar Tramvay Hattı
# 1                  Soğanlık                   M4 Kadıköy - SGH Metro Hattı
# 2                   Aksaray  M1A Yenikapı - Atatürk Havalimanı Metro Hattı
# 3                 Olimpiyat            M9 Bahariye - Olimpiyat Metro Hattı
# 4  Sağmalcılar-Pancar Motor      T4 Topkapı - Mescid-i Selam Tramvay Hattı
#
#   HAT_TURU        lat        lon      TYPE
# 0  Tramvay  41.005800  28.881681  existing
# 1    Metro  40.913288  29.192398  existing
# 2    Metro  41.012008  28.948090  existing
# 3    Metro  41.079466  28.767234  existing
# 4  Tramvay  41.057280  28.906940  existing

# %%
candidate_stations_df.head()
# Out:
#   station_id        lat     lon       TYPE
# 0     (0, 0)  40.979717  28.705  candidate
# 1     (0, 1)  40.979717  28.715  candidate
# 2     (0, 2)  40.979717  28.725  candidate
# 3     (0, 3)  40.979717  28.735  candidate
# 4     (0, 4)  40.979717  28.745  candidate

# %%
all_stations = pd.concat([
    candidate_stations_df[['station_id', 'lat', 'lon' , 'TYPE']],
    stations_df[['ISTASYON', 'lat', 'lon' , 'TYPE']].rename(columns={'ISTASYON': 'station_id'})
]).reset_index(drop=True)

# %%
all_stations = all_stations.reset_index(drop=True)
all_stations['station_id'] = all_stations.index + 34001

# %%
all_stations.head()
# Out:
#    station_id        lat     lon       TYPE
# 0       34001  40.979717  28.705  candidate
# 1       34002  40.979717  28.715  candidate
# 2       34003  40.979717  28.725  candidate
# 3       34004  40.979717  28.735  candidate
# 4       34005  40.979717  28.745  candidate

# %%
all_stations_pop = calculate_population_per_station(all_stations , population_df)

# %%
all_stations_pop_filtered = all_stations_pop[
    ~((all_stations_pop['arrived_population'] < 1000) & (all_stations_pop['TYPE'] == 'candidate'))
]

all_stations_pop_filtered = all_stations_pop_filtered.sort_values(by='arrived_population' , ascending = False)

# %%
all_stations_pop_filtered.head()
# Out:
#       station_id        lat        lon       TYPE  arrived_population
# 164        34165  41.006883  28.845000  candidate              302574
# 134        34135  41.001450  28.845000  candidate              294879
# 104        34105  40.996017  28.845000  candidate              261326
# 225        34226  41.017750  28.855000  candidate              259554
# 1177       35178  41.019391  28.857845   existing              235721

# %%
all_stations_pop_filtered.describe()
# Out:
#          station_id         lat         lon  arrived_population
# count    866.000000  866.000000  866.000000          866.000000
# mean   34654.267898   41.034148   28.910335        71616.110855
# std      383.173053    0.055695    0.126874        48453.873690
# min    34001.000000   40.784064   28.670765            0.000000
# 25%    34318.250000   41.006883   28.825000        34711.500000
# 50%    34605.500000   41.034050   28.895000        66030.500000
# 75%    35026.750000   41.068220   28.965000       102849.500000
# max    35243.000000   41.256408   29.409966       302574.000000

# %%
from collections import defaultdict
import re

# Eşleştirme toleransı (örneğin 0.0005 derece, yani yaklaşık 50 metre)
TOLERANCE = 0.0005

# Boş dictionary (defaultdict ile list olarak başlatılıyor)
project_dict = defaultdict(list)

# existing istasyonları filtrele
existing_stations = all_stations_pop[all_stations_pop['TYPE'] == 'existing']

# Her proje için istasyonları eşle
for idx, row in stations_df.iterrows():
    proje_adi_full = row['PROJE_ADI']
    lat = row['lat']
    lon = row['lon']

    # Hat kodunu ayıkla: Örneğin "M1A", "T4", "M11"
    match_hat = re.search(r'\b(M\d+[A-Z]?|T\d+)\b', proje_adi_full)
    if not match_hat:
        continue  # Hat kodu yoksa atla
    hat_kodu = match_hat.group()

    # Bu projedeki istasyonun konumuna yakın existing istasyonu bul
    match = existing_stations[
        (existing_stations['lat'].sub(lat).abs() < TOLERANCE) &
        (existing_stations['lon'].sub(lon).abs() < TOLERANCE)
    ]

    if not match.empty:
        for station_id in match['station_id']:
            project_dict[hat_kodu].append(station_id)

# Sonuç dict olarak:
project_dict = dict(project_dict)

# %%
print(project_dict)
# Out:
# {'T1': [34901, 34917, 34925, 34927, 34931, 34932, 34933, 34955, 34956, 34965, 34966, 34971, 34975, 34994, 34995, 34997, 35001, 35007, 35025, 35026, 35027, 35028, 35031, 35035, 35050, 35051, 35054, 35085, 35093, 35096, 35109, 35124], 'M4': [34902, 34909, 34910, 34938, 34991, 34999, 35010, 35012, 35029, 35034, 35039, 35053, 35057, 35024, 35058, 35062, 35065, 35081, 35086, 35092, 35161, 35162, 35163, 35164, 35165, 35166, 35167, 35168, 35169, 35170], 'M1A': [34903, 34941, 34945, 34947, 34958, 34961, 34969, 34998, 35003, 35033, 35048, 35083, 35084, 35090, 35097, 35099, 35111, 35112, 35114], 'M9': [34904, 34984, 35087, 35060, 35130, 35150, 35183, 35184, 35185, 35186, 35187, 35188, 35226, 35189, 35014, 35190, 35191], 'T4': [34905, 34906, 34923, 34940, 34942, 34948, 34964, 34967, 34968, 34972, 34973, 34974, 34996, 35002, 35008, 35032, 35056, 35063, 35091, 35098, 35110, 35115], 'M5': [34912, 34914, 34979, 35011, 35015, 35018, 35041, 35044, 35047, 35067, 35071, 35073, 35075, 35076, 35077, 35100, 35117, 35154, 35155, 35156, 35157, 35158, 35159, 35160], 'M7': [34915, 34937, 34952, 34953, 34978, 34980, 34982, 35013, 35016, 35021, 35043, 35046, 35070, 35103, 35107, 35119, 35120, 35121, 35122, 35201, 35202, 35203, 35204, 35205, 35206, 35207, 35208, 35209, 35210, 35242], 'T3': [34916, 34929, 34946, 34962, 34988, 34992, 34993, 35030, 35080, 35113], 'T5': [34918, 34919, 34920, 34922, 34939, 34959, 35055, 35125, 35126, 35127, 35182, 35214, 35243], 'M2': [34924, 35116, 34930, 34944, 34960, 34963, 34989, 34990, 35004, 35005, 35009, 35049, 35064, 35066, 35082, 35094, 34924, 35116, 35123], 'M3': [34926, 34957, 34928, 34943, 34970, 35006, 35037, 35060, 35130, 35061, 35089, 35174, 35177, 35178, 35180, 35181, 35211, 35212, 35227, 35228, 35229, 35230], 'M6': [34949, 35040, 35059, 35088], 'M1B': [34926, 34957, 35036, 35038, 35052, 35095, 35175, 35176, 35179, 35213, 35216, 35219, 35221, 35222, 35188, 35226], 'M8': [35118, 35171, 35172, 35173, 35192, 35193, 35194, 35195, 35196, 35197, 35198, 35199, 35200], 'M11': [35140, 35141, 35142, 35143, 35144, 35145, 35146, 35147, 35215, 35218, 35220, 35223, 35224, 35225], 'M10': [35151, 35152], 'M12': [35231, 35232, 35233, 35234, 35235, 35236, 35237, 35238, 35239, 35240, 35241]}

# %%
connectivity_dict = calculate_connectivity_dict(all_stations_pop)

# %%
print(len(connectivity_dict))
# Out:
# 1240

# %%
GeneticAlgorithm = GeneticMetroPlanner(
    all_stations_df = all_stations_pop_filtered,
    connectivity_dict = connectivity_dict,
    existing_lines_dict = project_dict)

# %%
chromosome = GeneticAlgorithm.generate_chromosome()
for line, stations in chromosome.items():
    print(f"{line}: {len(stations)} istasyon")
# Out:
# T1: 33 istasyon
# M4: 30 istasyon
# M1A: 19 istasyon
# M9: 18 istasyon
# T4: 24 istasyon
# M5: 29 istasyon
# M7: 32 istasyon
# T3: 10 istasyon
# T5: 15 istasyon
# M2: 19 istasyon
# M3: 23 istasyon
# M6: 9 istasyon
# M1B: 18 istasyon
# M8: 13 istasyon
# M11: 16 istasyon
# M10: 2 istasyon
# M12: 11 istasyon

# %%
for line , stations in project_dict.items():
    print(f"{line}:  {len(stations)} istasyon")
# Out:
# T1:  32 istasyon
# M4:  30 istasyon
# M1A:  19 istasyon
# M9:  17 istasyon
# T4:  22 istasyon
# M5:  24 istasyon
# M7:  30 istasyon
# T3:  10 istasyon
# T5:  13 istasyon
# M2:  19 istasyon
# M3:  22 istasyon
# M6:  4 istasyon
# M1B:  16 istasyon
# M8:  13 istasyon
# M11:  14 istasyon
# M10:  2 istasyon
# M12:  11 istasyon

# %%
print(chromosome)
# Out:
# {'T1': [34901, 34917, 34925, 34927, 34931, 34932, 34933, 34955, 34956, 34965, 34966, 34971, 34975, 34994, 34995, 34997, 35001, 35007, 35025, 35026, 35027, 35028, 35031, 35035, 35050, 35051, 35054, 35085, 35093, 35096, 35109, 35124, 34197], 'M4': [34902, 34909, 34910, 34938, 34991, 34999, 35010, 35012, 35029, 35034, 35039, 35053, 35057, 35024, 35058, 35062, 35065, 35081, 35086, 35092, 35161, 35162, 35163, 35164, 35165, 35166, 35167, 35168, 35169, 35170], 'M1A': [34903, 34941, 34945, 34947, 34958, 34961, 34969, 34998, 35003, 35033, 35048, 35083, 35084, 35090, 35097, 35099, 35111, 35112, 35114], 'M9': [34904, 34984, 35087, 35060, 35130, 35150, 35183, 35184, 35185, 35186, 35187, 35188, 35226, 35189, 35014, 35190, 35191, 34544], 'T4': [34905, 34906, 34923, 34940, 34942, 34948, 34964, 34967, 34968, 34972, 34973, 34974, 34996, 35002, 35008, 35032, 35056, 35063, 35091, 35098, 35110, 35115, 34382, 34236], 'M5': [34912, 34914, 34979, 35011, 35015, 35018, 35041, 35044, 35047, 35067, 35071, 35073, 35075, 35076, 35077, 35100, 35117, 35154, 35155, 35156, 35157, 35158, 35159, 35160, 34269, 34300, 34329, 34299, 34360], 'M7': [34915, 34937, 34952, 34953, 34978, 34980, 34982, 35013, 35016, 35021, 35043, 35046, 35070, 35103, 35107, 35119, 35120, 35121, 35122, 35201, 35202, 35203, 35204, 35205, 35206, 35207, 35208, 35209, 35210, 35242, 34630, 34515], 'T3': [34916, 34929, 34946, 34962, 34988, 34992, 34993, 35030, 35080, 35113], 'T5': [34918, 34919, 34920, 34922, 34939, 34959, 35055, 35125, 35126, 35127, 35182, 35214, 35243, 34657, 34265], 'M2': [34924, 35116, 34930, 34944, 34960, 34963, 34989, 34990, 35004, 35005, 35009, 35049, 35064, 35066, 35082, 35094, 34924, 35116, 35123], 'M3': [34926, 34957, 34928, 34943, 34970, 35006, 35037, 35060, 35130, 35061, 35089, 35174, 35177, 35178, 35180, 35181, 35211, 35212, 35227, 35228, 35229, 35230, 34254], 'M6': [34949, 35040, 35059, 35088, 34660, 34569, 34479, 34510, 34629], 'M1B': [34926, 34957, 35036, 35038, 35052, 35095, 35175, 35176, 35179, 35213, 35216, 35219, 35221, 35222, 35188, 35226, 34228, 34347], 'M8': [35118, 35171, 35172, 35173, 35192, 35193, 35194, 35195, 35196, 35197, 35198, 35199, 35200], 'M11': [35140, 35141, 35142, 35143, 35144, 35145, 35146, 35147, 35215, 35218, 35220, 35223, 35224, 35225, 34579, 34338], 'M10': [35151, 35152], 'M12': [35231, 35232, 35233, 35234, 35235, 35236, 35237, 35238, 35239, 35240, 35241]}

# %%
m = visualize_chromosome(chromosome , all_stations)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 m = visualize_chromosome(chromosome , all_stations)
#
# NameError: name 'visualize_chromosome' is not defined
